# %%
import json
import os
import re
import sys

import pandas as pd
import numpy as np

sys.path.append(os.path.dirname(os.path.abspath('')))

from app.utils import translit
from app.settings import TRANSPORT_TYPE_COLORS, TRANSPORT_TYPE_NAMES

# %%
df1 = pd.read_excel("./monday.xlsx")
df2 = pd.read_excel("./saturday.xlsx")
df3 = pd.read_excel("./sunday.xlsx")

data_columns = []
columns = {
    df1.columns[0]: "name" 
}
for i in range(1, len(df1.columns)):
    new_name = f"data{i}"
    columns[df1.columns[i]] = new_name
    data_columns.append(new_name)
    
df1.rename(columns=columns, inplace=True)
df2.rename(columns=columns, inplace=True)
df3.rename(columns=columns, inplace=True)
df1.head(10)
# Out:
#                              name                            data1  data2  \
# 0                             NaN                              NaN    NaN
# 1                 В будничные дни                              NaN    NaN
# 2                             NaN                              NaN    NaN
# 3                        МАРШРУТЫ  ВРЕМЯ ОТПРАВЛЕНИЯ С АВТОВОКЗАЛА    NaN
# 4  №2 Автовокзал - Старокамышинск                             5:15   5:45
# 5                             NaN                            10:25  10:36
# 6                             NaN                            15:56  16:10
# 7                             NaN                            21:03  21:30
# 8    №4 Автовокзал - ДК Петяркова                             6:05   6:55
# 9                             NaN                            17:28  19:05
#
#    data3  data4  data5  data6  data7  data8  data9 data10 data11 data12
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   6:00   6:15   6:38   7:11   7:26   7:41   8:04   8:37   9:05   9:32
# 5  10:58  11:13  11:51  12:22  12:39  13:15  14:08  14:30  14:56  15:34
# 6  16:22  17:04  17:36  17:48  18:02  19:02  19:15  19:33  20:04  20:38
# 7  22:00  23:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8   7:45   8:40   9:33  11:25  12:15  13:05  13:55  14:55  15:45  16:35
# 9  19:55  20:45  21:35  22:25    NaN    NaN    NaN    NaN    NaN    NaN

# %%
routes = {}

name = ''
times = []

def update_route_data(routes, name, times_name, times):
    if not times:
        return
    
    key = re.sub(r'[^\w]', '', str(name).lower())
    
    if times_name != 'monday' and key not in routes:
        raise Exception(f'Unknown route {name}')
    
    if key not in routes:
        routes[key] = {
            'name': name,
            'monday': [],
            'saturday': [],
            'sunday': [],
        }
    routes[key][times_name] = times

for df, times_name in (
    (df1, 'monday',),
    (df2, 'saturday',),
    (df3, 'sunday',),
):
    df = df.replace({np.nan: None})
    for index, data in df.iterrows():
        if not data['data1']:
            continue
        if 'время' in str(data['data1']).lower():
            continue
        if data['name']:
            update_route_data(routes, name, times_name, times)
            name = data['name']
            times = []
        for i in data_columns:
            if data[i]:
                times.append(data[i])
    update_route_data(routes, name, 'monday', times)
    
def get_json_data(route):
    if route['monday'] == route['saturday']:
        return (
            (route['name'], ('Будни и Суббота', 'Воскресенье и праздники'), (route['monday'], route['sunday'])),
        )
    elif route['saturday'] == route['sunday']:
        return (
            (route['name'], ('Будни', 'Выходные и праздники'), (route['monday'], route['sunday'])),
        )
    else:
        return (
            (route['name'], ('Будни', ''), (route['monday'], [])),
            (route['name'], ('Суббота', ''), (route['saturday'], [])),
            (route['name'], ('Воскресенье и праздники', ''), (route['sunday'], [])),
        )
    
def get_json_payload(name, titles_list, times_list):
    rows = []
    for times in times_list:
        current_dict = {}
        for item in times:
            hour, minute = item.split(":")
            hour = hour.zfill(2)
            minute = minute.zfill(2)
            if hour not in current_dict:
                current_dict[hour] = []
            current_dict[hour].append(minute)
        for _, v in current_dict.items():
            if "" not in v:
                v.append("")
        rows.append(
            {
                "timesByHour": current_dict,
            }
        )
    
    payload = {
        "head": {
            "type": TRANSPORT_TYPE_NAMES["bus"],
            "routeNumber": name.split(' ')[0],
            "color": TRANSPORT_TYPE_COLORS["bus"],
            "direction": name,
            "description": ".",
            "shiftMinutes": 0,
            "pdfFilename": translit(name),
        },
        "body": {
            "columnHeads": titles_list,
            "rows": [
                {
                    "name": "Рейсы",
                    "columns": rows,
                }
            ],
        },
        "commentBottom": [],
    }
        
    return payload
    
for route in routes.values():
    for data in get_json_data(route):
        payload = get_json_payload(*data)
        payload = json.dumps(payload, indent=4, ensure_ascii=False)
        print('---------------------------------------------------------------------------')
        print(data[0])
        print('---------------------------------------------------------------------------')
        print(str(payload))
        print('\n\n')
# Out:
# ---------------------------------------------------------------------------
# №2 Автовокзал - Старокамышинск
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№2",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№2 Автовокзал - Старокамышинск",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№2_Avtovokzal_-_Starokamysinsk"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "15",
#                                 "45",
#                                 ""
#                             ],
#                             "06": [
#                                 "00",
#                                 "15",
#                                 "38",
#                                 ""
#                             ],
#                             "07": [
#                                 "11",
#                                 "26",
#                                 "41",
#                                 ""
#                             ],
#                             "08": [
#                                 "04",
#                                 "37",
#                                 ""
#                             ],
#                             "09": [
#                                 "05",
#                                 "32",
#                                 ""
#                             ],
#                             "10": [
#                                 "25",
#                                 "36",
#                                 "58",
#                                 ""
#                             ],
#                             "11": [
#                                 "13",
#                                 "51",
#                                 ""
#                             ],
#                             "12": [
#                                 "22",
#                                 "39",
#                                 ""
#                             ],
#                             "13": [
#                                 "15",
#                                 ""
#                             ],
#                             "14": [
#                                 "08",
#                                 "30",
#                                 "56",
#                                 ""
#                             ],
#                             "15": [
#                                 "34",
#                                 "56",
#                                 ""
#                             ],
#                             "16": [
#                                 "10",
#                                 "22",
#                                 ""
#                             ],
#                             "17": [
#                                 "04",
#                                 "36",
#                                 "48",
#                                 ""
#                             ],
#                             "18": [
#                                 "02",
#                                 ""
#                             ],
#                             "19": [
#                                 "02",
#                                 "15",
#                                 "33",
#                                 ""
#                             ],
#                             "20": [
#                                 "04",
#                                 "38",
#                                 ""
#                             ],
#                             "21": [
#                                 "03",
#                                 "30",
#                                 ""
#                             ],
#                             "22": [
#                                 "00",
#                                 ""
#                             ],
#                             "23": [
#                                 "00",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "20",
#                                 "48",
#                                 ""
#                             ],
#                             "06": [
#                                 "16",
#                                 "45",
#                                 ""
#                             ],
#                             "07": [
#                                 "13",
#                                 "41",
#                                 ""
#                             ],
#                             "08": [
#                                 "10",
#                                 "38",
#                                 ""
#                             ],
#                             "09": [
#                                 "06",
#                                 ""
#                             ],
#                             "10": [
#                                 "11",
#                                 "39",
#                                 ""
#                             ],
#                             "11": [
#                                 "07",
#                                 "36",
#                                 ""
#                             ],
#                             "12": [
#                                 "04",
#                                 "32",
#                                 ""
#                             ],
#                             "13": [
#                                 "01",
#                                 "29",
#                                 "57",
#                                 ""
#                             ],
#                             "14": [
#                                 "39",
#                                 ""
#                             ],
#                             "15": [
#                                 "07",
#                                 "35",
#                                 ""
#                             ],
#                             "16": [
#                                 "04",
#                                 "32",
#                                 ""
#                             ],
#                             "17": [
#                                 "00",
#                                 "29",
#                                 "57",
#                                 ""
#                             ],
#                             "18": [
#                                 "25",
#                                 ""
#                             ],
#                             "19": [
#                                 "30",
#                                 "58",
#                                 ""
#                             ],
#                             "20": [
#                                 "26",
#                                 "55",
#                                 ""
#                             ],
#                             "21": [
#                                 "23",
#                                 "51",
#                                 ""
#                             ],
#                             "22": [
#                                 "20",
#                                 "50",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №4 Автовокзал - ДК Петяркова
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№4",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№4 Автовокзал - ДК Петяркова",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№4_Avtovokzal_-_DK_Petarkova"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "07": [
#                                 "45",
#                                 ""
#                             ],
#                             "08": [
#                                 "40",
#                                 ""
#                             ],
#                             "09": [
#                                 "33",
#                                 ""
#                             ],
#                             "11": [
#                                 "25",
#                                 ""
#                             ],
#                             "12": [
#                                 "15",
#                                 ""
#                             ],
#                             "13": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "14": [
#                                 "55",
#                                 ""
#                             ],
#                             "15": [
#                                 "45",
#                                 ""
#                             ],
#                             "16": [
#                                 "35",
#                                 ""
#                             ],
#                             "17": [
#                                 "28",
#                                 ""
#                             ],
#                             "19": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "20": [
#                                 "45",
#                                 ""
#                             ],
#                             "21": [
#                                 "35",
#                                 ""
#                             ],
#                             "22": [
#                                 "25",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "07": [
#                                 "45",
#                                 ""
#                             ],
#                             "08": [
#                                 "40",
#                                 ""
#                             ],
#                             "09": [
#                                 "33",
#                                 ""
#                             ],
#                             "11": [
#                                 "25",
#                                 ""
#                             ],
#                             "12": [
#                                 "15",
#                                 ""
#                             ],
#                             "13": [
#                                 "05",
#                                 ""
#                             ],
#                             "14": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "15": [
#                                 "45",
#                                 ""
#                             ],
#                             "16": [
#                                 "35",
#                                 ""
#                             ],
#                             "17": [
#                                 "28",
#                                 ""
#                             ],
#                             "19": [
#                                 "05",
#                                 "55",
#                                 ""
#                             ],
#                             "20": [
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №5 Автовокзал - Потанино
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№5",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№5 Автовокзал - Потанино",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№5_Avtovokzal_-_Potanino"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "20",
#                                 "35",
#                                 "50",
#                                 ""
#                             ],
#                             "06": [
#                                 "06",
#                                 "21",
#                                 "36",
#                                 "52",
#                                 ""
#                             ],
#                             "07": [
#                                 "07",
#                                 "22",
#                                 "38",
#                                 "53",
#                                 ""
#                             ],
#                             "08": [
#                                 "08",
#                                 "24",
#                                 "39",
#                                 "55",
#                                 ""
#                             ],
#                             "09": [
#                                 "30",
#                                 "48",
#                                 ""
#                             ],
#                             "10": [
#                                 "10",
#                                 "52",
#                                 ""
#                             ],
#                             "11": [
#                                 "19",
#                                 "42",
#                                 ""
#                             ],
#                             "12": [
#                                 "05",
#                                 "28",
#                                 "51",
#                                 ""
#                             ],
#                             "13": [
#                                 "14",
#                                 "37",
#                                 ""
#                             ],
#                             "14": [
#                                 "00",
#                                 "23",
#                                 "46",
#                                 ""
#                             ],
#                             "15": [
#                                 "09",
#                                 "24",
#                                 "39",
#                                 "55",
#                                 ""
#                             ],
#                             "16": [
#                                 "10",
#                                 "25",
#                                 "41",
#                                 "56",
#                                 ""
#                             ],
#                             "17": [
#                                 "11",
#                                 "27",
#                                 "42",
#                                 "57",
#                                 ""
#                             ],
#                             "18": [
#                                 "24",
#                                 "49",
#                                 ""
#                             ],
#                             "19": [
#                                 "32",
#                                 "52",
#                                 ""
#                             ],
#                             "20": [
#                                 "15",
#                                 "35",
#                                 ""
#                             ],
#                             "21": [
#                                 "00",
#                                 "20",
#                                 "42",
#                                 ""
#                             ],
#                             "22": [
#                                 "02",
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №5 Автовокзал - Потанино
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№5",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№5 Автовокзал - Потанино",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№5_Avtovokzal_-_Potanino"
#     },
#     "body": {
#         "columnHeads": [
#             "Суббота",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "06",
#                                 "29",
#                                 "52",
#                                 ""
#                             ],
#                             "07": [
#                                 "15",
#                                 "38",
#                                 ""
#                             ],
#                             "08": [
#                                 "01",
#                                 "24",
#                                 "47",
#                                 ""
#                             ],
#                             "09": [
#                                 "33",
#                                 ""
#                             ],
#                             "10": [
#                                 "19",
#                                 ""
#                             ],
#                             "11": [
#                                 "05",
#                                 "28",
#                                 "51",
#                                 ""
#                             ],
#                             "12": [
#                                 "14",
#                                 "37",
#                                 ""
#                             ],
#                             "13": [
#                                 "00",
#                                 "23",
#                                 "46",
#                                 ""
#                             ],
#                             "14": [
#                                 "32",
#                                 "55",
#                                 ""
#                             ],
#                             "15": [
#                                 "18",
#                                 "41",
#                                 ""
#                             ],
#                             "16": [
#                                 "04",
#                                 "27",
#                                 "50",
#                                 ""
#                             ],
#                             "17": [
#                                 "13",
#                                 "59",
#                                 ""
#                             ],
#                             "18": [
#                                 "22",
#                                 ""
#                             ],
#                             "19": [
#                                 "08",
#                                 "31",
#                                 "54",
#                                 ""
#                             ],
#                             "20": [
#                                 "17",
#                                 "40",
#                                 ""
#                             ],
#                             "21": [
#                                 "05",
#                                 "30",
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №5 Автовокзал - Потанино
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№5",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№5 Автовокзал - Потанино",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№5_Avtovokzal_-_Potanino"
#     },
#     "body": {
#         "columnHeads": [
#             "Воскресенье и праздники",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "06",
#                                 "29",
#                                 "52",
#                                 ""
#                             ],
#                             "07": [
#                                 "15",
#                                 "38",
#                                 ""
#                             ],
#                             "08": [
#                                 "01",
#                                 "24",
#                                 "47",
#                                 ""
#                             ],
#                             "09": [
#                                 "10",
#                                 "37",
#                                 ""
#                             ],
#                             "10": [
#                                 "29",
#                                 ""
#                             ],
#                             "11": [
#                                 "12",
#                                 "58",
#                                 ""
#                             ],
#                             "12": [
#                                 "44",
#                                 ""
#                             ],
#                             "13": [
#                                 "30",
#                                 "53",
#                                 ""
#                             ],
#                             "14": [
#                                 "16",
#                                 "39",
#                                 ""
#                             ],
#                             "15": [
#                                 "02",
#                                 "25",
#                                 "48",
#                                 ""
#                             ],
#                             "16": [
#                                 "11",
#                                 "34",
#                                 "57",
#                                 ""
#                             ],
#                             "17": [
#                                 "27",
#                                 ""
#                             ],
#                             "18": [
#                                 "13",
#                                 "59",
#                                 ""
#                             ],
#                             "19": [
#                                 "45",
#                                 ""
#                             ],
#                             "20": [
#                                 "31",
#                                 ""
#                             ],
#                             "21": [
#                                 "13",
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №6 Кольцевой по ул. Сутягина
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№6",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№6 Кольцевой по ул. Сутягина",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№6_Kol_zevoj_po_ul._Sutagina"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "50",
#                                 ""
#                             ],
#                             "06": [
#                                 "30",
#                                 ""
#                             ],
#                             "07": [
#                                 "10",
#                                 ""
#                             ],
#                             "08": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ],
#                             "09": [
#                                 "30",
#                                 ""
#                             ],
#                             "11": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ],
#                             "12": [
#                                 "30",
#                                 ""
#                             ],
#                             "13": [
#                                 "10",
#                                 ""
#                             ],
#                             "14": [
#                                 "05",
#                                 "45",
#                                 ""
#                             ],
#                             "15": [
#                                 "30",
#                                 ""
#                             ],
#                             "16": [
#                                 "15",
#                                 ""
#                             ],
#                             "17": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ],
#                             "18": [
#                                 "33",
#                                 ""
#                             ],
#                             "20": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "07": [
#                                 "10",
#                                 ""
#                             ],
#                             "08": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ],
#                             "09": [
#                                 "30",
#                                 ""
#                             ],
#                             "11": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ],
#                             "12": [
#                                 "30",
#                                 ""
#                             ],
#                             "13": [
#                                 "10",
#                                 ""
#                             ],
#                             "14": [
#                                 "05",
#                                 "45",
#                                 ""
#                             ],
#                             "15": [
#                                 "30",
#                                 ""
#                             ],
#                             "16": [
#                                 "15",
#                                 ""
#                             ],
#                             "17": [
#                                 "02",
#                                 "45",
#                                 ""
#                             ],
#                             "18": [
#                                 "33",
#                                 ""
#                             ],
#                             "20": [
#                                 "00",
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №6 Кольцевой по пр. Славы
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№6",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№6 Кольцевой по пр. Славы",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№6_Kol_zevoj_po_pr._Slavy"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "55",
#                                 ""
#                             ],
#                             "06": [
#                                 "35",
#                                 ""
#                             ],
#                             "07": [
#                                 "15",
#                                 "55",
#                                 ""
#                             ],
#                             "08": [
#                                 "35",
#                                 ""
#                             ],
#                             "09": [
#                                 "20",
#                                 ""
#                             ],
#                             "10": [
#                                 "08",
#                                 ""
#                             ],
#                             "11": [
#                                 "25",
#                                 ""
#                             ],
#                             "12": [
#                                 "05",
#                                 "45",
#                                 ""
#                             ],
#                             "13": [
#                                 "40",
#                                 ""
#                             ],
#                             "14": [
#                                 "20",
#                                 ""
#                             ],
#                             "15": [
#                                 "00",
#                                 "40",
#                                 ""
#                             ],
#                             "16": [
#                                 "55",
#                                 ""
#                             ],
#                             "17": [
#                                 "40",
#                                 ""
#                             ],
#                             "18": [
#                                 "25",
#                                 ""
#                             ],
#                             "19": [
#                                 "10",
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "07": [
#                                 "15",
#                                 "55",
#                                 ""
#                             ],
#                             "08": [
#                                 "35",
#                                 ""
#                             ],
#                             "09": [
#                                 "20",
#                                 ""
#                             ],
#                             "10": [
#                                 "08",
#                                 ""
#                             ],
#                             "11": [
#                                 "25",
#                                 ""
#                             ],
#                             "12": [
#                                 "05",
#                                 "45",
#                                 ""
#                             ],
#                             "13": [
#                                 "40",
#                                 ""
#                             ],
#                             "14": [
#                                 "20",
#                                 ""
#                             ],
#                             "15": [
#                                 "00",
#                                 "40",
#                                 ""
#                             ],
#                             "16": [
#                                 "55",
#                                 ""
#                             ],
#                             "17": [
#                                 "40",
#                                 ""
#                             ],
#                             "18": [
#                                 "25",
#                                 ""
#                             ],
#                             "19": [
#                                 "10",
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №7 Автовокзал - П. Вахрушево
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№7",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№7 Автовокзал - П. Вахрушево",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№7_Avtovokzal_-_P._Vahrusevo"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "05",
#                                 "31",
#                                 ""
#                             ],
#                             "06": [
#                                 "23",
#                                 "49",
#                                 ""
#                             ],
#                             "07": [
#                                 "15",
#                                 "32",
#                                 "58",
#                                 ""
#                             ],
#                             "08": [
#                                 "24",
#                                 "50",
#                                 ""
#                             ],
#                             "09": [
#                                 "16",
#                                 "42",
#                                 ""
#                             ],
#                             "10": [
#                                 "38",
#                                 ""
#                             ],
#                             "11": [
#                                 "14",
#                                 "56",
#                                 ""
#                             ],
#                             "12": [
#                                 "22",
#                                 "50",
#                                 ""
#                             ],
#                             "13": [
#                                 "32",
#                                 ""
#                             ],
#                             "14": [
#                                 "22",
#                                 "54",
#                                 ""
#                             ],
#                             "15": [
#                                 "20",
#                                 "58",
#                                 ""
#                             ],
#                             "16": [
#                                 "30",
#                                 "56",
#                                 ""
#                             ],
#                             "17": [
#                                 "22",
#                                 "48",
#                                 ""
#                             ],
#                             "18": [
#                                 "14",
#                                 "40",
#                                 ""
#                             ],
#                             "19": [
#                                 "16",
#                                 ""
#                             ],
#                             "20": [
#                                 "02",
#                                 "44",
#                                 ""
#                             ],
#                             "21": [
#                                 "38",
#                                 ""
#                             ],
#                             "22": [
#                                 "20",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "17",
#                                 ""
#                             ],
#                             "06": [
#                                 "43",
#                                 ""
#                             ],
#                             "07": [
#                                 "16",
#                                 "49",
#                                 ""
#                             ],
#                             "08": [
#                                 "22",
#                                 "55",
#                                 ""
#                             ],
#                             "09": [
#                                 "28",
#                                 ""
#                             ],
#                             "10": [
#                                 "16",
#                                 ""
#                             ],
#                             "11": [
#                                 "04",
#                                 "37",
#                                 ""
#                             ],
#                             "12": [
#                                 "25",
#                                 "58",
#                                 ""
#                             ],
#                             "13": [
#                                 "26",
#                                 ""
#                             ],
#                             "14": [
#                                 "14",
#                                 ""
#                             ],
#                             "15": [
#                                 "02",
#                                 "50",
#                                 ""
#                             ],
#                             "16": [
#                                 "38",
#                                 ""
#                             ],
#                             "17": [
#                                 "11",
#                                 "44",
#                                 ""
#                             ],
#                             "18": [
#                                 "22",
#                                 ""
#                             ],
#                             "19": [
#                                 "00",
#                                 "53",
#                                 ""
#                             ],
#                             "20": [
#                                 "31",
#                                 ""
#                             ],
#                             "21": [
#                                 "30",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №8 Кольцевой по пр. Победы
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№8",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№8 Кольцевой по пр. Победы",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№8_Kol_zevoj_po_pr._Pobedy"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "08": [
#                                 "25",
#                                 ""
#                             ],
#                             "09": [
#                                 "04",
#                                 "43",
#                                 ""
#                             ],
#                             "10": [
#                                 "22",
#                                 ""
#                             ],
#                             "11": [
#                                 "01",
#                                 "40",
#                                 ""
#                             ],
#                             "14": [
#                                 "14",
#                                 "53",
#                                 ""
#                             ],
#                             "15": [
#                                 "32",
#                                 ""
#                             ],
#                             "16": [
#                                 "11",
#                                 "50",
#                                 ""
#                             ],
#                             "17": [
#                                 "29",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №8 Кольцевой по пр. Коммунистический
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№8",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№8 Кольцевой по пр. Коммунистический",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№8_Kol_zevoj_po_pr._Kommunisticeskij"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "07": [
#                                 "26",
#                                 ""
#                             ],
#                             "08": [
#                                 "05",
#                                 "44",
#                                 ""
#                             ],
#                             "09": [
#                                 "23",
#                                 ""
#                             ],
#                             "10": [
#                                 "02",
#                                 "41",
#                                 ""
#                             ],
#                             "13": [
#                                 "15",
#                                 "54",
#                                 ""
#                             ],
#                             "14": [
#                                 "33",
#                                 ""
#                             ],
#                             "15": [
#                                 "12",
#                                 "51",
#                                 ""
#                             ],
#                             "16": [
#                                 "30",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №10 Кольцевой по ул. Ленина
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№10",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№10 Кольцевой по ул. Ленина",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№10_Kol_zevoj_po_ul._Lenina"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             "Выходные и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "50",
#                                 ""
#                             ],
#                             "06": [
#                                 "07",
#                                 "23",
#                                 "40",
#                                 "57",
#                                 ""
# ...
#                                 ""
#                             ],
#                             "09": [
#                                 "00",
#                                 "25",
#                                 ""
#                             ],
#                             "10": [
#                                 "15",
#                                 "40",
#                                 ""
#                             ],
#                             "11": [
#                                 "05",
#                                 "30",
#                                 "55",
#                                 ""
#                             ],
#                             "12": [
#                                 "20",
#                                 "45",
#                                 ""
#                             ],
#                             "13": [
#                                 "10",
#                                 "35",
#                                 ""
#                             ],
#                             "14": [
#                                 "00",
#                                 "25",
#                                 "50",
#                                 ""
#                             ],
#                             "15": [
#                                 "15",
#                                 "40",
#                                 ""
#                             ],
#                             "16": [
#                                 "30",
#                                 "55",
#                                 ""
#                             ],
#                             "17": [
#                                 "20",
#                                 "45",
#                                 ""
#                             ],
#                             "18": [
#                                 "10",
#                                 "35",
#                                 ""
#                             ],
#                             "19": [
#                                 "00",
#                                 "30",
#                                 ""
#                             ],
#                             "20": [
#                                 "00",
#                                 "30",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "55",
#                                 ""
#                             ],
#                             "06": [
#                                 "35",
#                                 ""
#                             ],
#                             "07": [
#                                 "15",
#                                 "55",
#                                 ""
#                             ],
#                             "08": [
#                                 "35",
#                                 ""
#                             ],
#                             "09": [
#                                 "15",
#                                 ""
#                             ],
#                             "10": [
#                                 "30",
#                                 ""
#                             ],
#                             "11": [
#                                 "33",
#                                 ""
#                             ],
#                             "12": [
#                                 "30",
#                                 ""
#                             ],
#                             "13": [
#                                 "35",
#                                 ""
#                             ],
#                             "14": [
#                                 "15",
#                                 "57",
#                                 ""
#                             ],
#                             "15": [
#                                 "44",
#                                 ""
#                             ],
#                             "16": [
#                                 "20",
#                                 ""
#                             ],
#                             "17": [
#                                 "05",
#                                 "50",
#                                 ""
#                             ],
#                             "19": [
#                                 "39",
#                                 ""
#                             ],
#                             "20": [
#                                 "25",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №29 Автовокзал - ЧГРЭС
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№29",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№29 Автовокзал - ЧГРЭС",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№29_Avtovokzal_-_CGRES"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни и Суббота",
#             "Воскресенье и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "35",
#                                 ""
#                             ],
#                             "13": [
#                                 "10",
#                                 ""
#                             ],
#                             "17": [
#                                 "25",
#                                 ""
#                             ],
#                             "18": [
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "35",
#                                 ""
#                             ],
#                             "13": [
#                                 "10",
#                                 ""
#                             ],
#                             "17": [
#                                 "25",
#                                 ""
#                             ],
#                             "18": [
#                                 "45",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №30Б Автовокзал - Калачёво (через Бажово с заездом в Заозёрный)
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№30Б",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№30Б Автовокзал - Калачёво (через Бажово с заездом в Заозёрный)",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№30B_Avtovokzal_-_Kalacevo_(cerez_Bajovo_s_zaezdom_v_Zaozernyj)"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни и Суббота",
#             "Воскресенье и праздники"
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "05": [
#                                 "50",
#                                 ""
#                             ],
#                             "09": [
#                                 "03",
#                                 ""
#                             ],
#                             "12": [
#                                 "40",
#                                 ""
#                             ],
#                             "16": [
#                                 "30",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {
#                             "09": [
#                                 "03",
#                                 ""
#                             ],
#                             "12": [
#                                 "40",
#                                 ""
#                             ],
#                             "15": [
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №41 Автовокзал - ДК Петрякова (через центр города)
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№41",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№41 Автовокзал - ДК Петрякова (через центр города)",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№41_Avtovokzal_-_DK_Petrakova_(cerez_zentr_goroda)"
#     },
#     "body": {
#         "columnHeads": [
#             "Будни",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "50",
#                                 ""
#                             ],
#                             "08": [
#                                 "15",
#                                 ""
#                             ],
#                             "09": [
#                                 "36",
#                                 ""
#                             ],
#                             "10": [
#                                 "56",
#                                 ""
#                             ],
#                             "14": [
#                                 "50",
#                                 ""
#                             ],
#                             "16": [
#                                 "11",
#                                 ""
#                             ],
#                             "17": [
#                                 "35",
#                                 ""
#                             ],
#                             "18": [
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №41 Автовокзал - ДК Петрякова (через центр города)
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№41",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№41 Автовокзал - ДК Петрякова (через центр города)",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№41_Avtovokzal_-_DK_Petrakova_(cerez_zentr_goroda)"
#     },
#     "body": {
#         "columnHeads": [
#             "Суббота",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "50",
#                                 ""
#                             ],
#                             "07": [
#                                 "30",
#                                 ""
#                             ],
#                             "08": [
#                                 "15",
#                                 "55",
#                                 ""
#                             ],
#                             "09": [
#                                 "36",
#                                 ""
#                             ],
#                             "10": [
#                                 "56",
#                                 ""
#                             ],
#                             "12": [
#                                 "16",
#                                 ""
#                             ],
#                             "13": [
#                                 "30",
#                                 ""
#                             ],
#                             "14": [
#                                 "50",
#                                 ""
#                             ],
#                             "16": [
#                                 "11",
#                                 "51",
#                                 ""
#                             ],
#                             "17": [
#                                 "35",
#                                 ""
#                             ],
#                             "18": [
#                                 "15",
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
#
#
#
# ---------------------------------------------------------------------------
# №41 Автовокзал - ДК Петрякова (через центр города)
# ---------------------------------------------------------------------------
# {
#     "head": {
#         "type": "Автобус",
#         "routeNumber": "№41",
#         "color": [
#             85,
#             22,
#             100,
#             13
#         ],
#         "direction": "№41 Автовокзал - ДК Петрякова (через центр города)",
#         "description": ".",
#         "shiftMinutes": 0,
#         "pdfFilename": "№41_Avtovokzal_-_DK_Petrakova_(cerez_zentr_goroda)"
#     },
#     "body": {
#         "columnHeads": [
#             "Воскресенье и праздники",
#             ""
#         ],
#         "rows": [
#             {
#                 "name": "Рейсы",
#                 "columns": [
#                     {
#                         "timesByHour": {
#                             "06": [
#                                 "50",
#                                 ""
#                             ],
#                             "08": [
#                                 "15",
#                                 ""
#                             ],
#                             "09": [
#                                 "36",
#                                 ""
#                             ],
#                             "10": [
#                                 "56",
#                                 ""
#                             ],
#                             "14": [
#                                 "50",
#                                 ""
#                             ],
#                             "16": [
#                                 "11",
#                                 ""
#                             ],
#                             "17": [
#                                 "35",
#                                 ""
#                             ],
#                             "18": [
#                                 "55",
#                                 ""
#                             ]
#                         }
#                     },
#                     {
#                         "timesByHour": {}
#                     }
#                 ]
#             }
#         ]
#     },
#     "commentBottom": []
# }
